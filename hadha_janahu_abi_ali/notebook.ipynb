# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
df = pd.read_pickle('./poems_abu_alalaa.pkl')

# %%
df = df.sort_values(['verses'], ascending=False).reset_index(drop=True)

# %%
df.describe()
# Out:
#             verses
# count  1612.000000
# mean      7.377171
# std       8.367442
# min       2.000000
# 25%       3.000000
# 50%       5.000000
# 75%       8.000000
# max      96.000000

# %%
df = df[df['verses'] >= 6].reset_index(drop=True)

# %%
df
# Out:
#                              title             url  topic  \
# 0            ترنم في نهارك مستعينا  poem22214.html  دينية
# 1         أعن وخد القلاص كشفت حالا  poem23633.html   عامه
# 2         يرومك والجوزاء دون مرامه  poem23642.html   عامه
# 3    يا ساهر البرق أيقظ راقد السمر  poem23634.html   عامه
# 4          أودى فليت الحادثات كفاف  poem23630.html   عامه
# ..                             ...             ...    ...
# 746      باهى رجال وفي جهل يباهونا  poem23477.html  قصيره
# 747             تنافس قوم على رتبة  poem22379.html   عامه
# 748             تدين مغربي بانتحال  poem23605.html  قصيره
# 749   قد نال خيرا في المعاشر ظاهرا  poem22018.html  قصيره
# 750           ما خص مصرا وبأ وحدها  poem22035.html  قصيره
#
#                    topic_url     meter          meter_url  verses
# 0    Poems-Topics-دينية.html    الوافر    sea-الوافر.html      96
# 1     Poems-Topics-عامه.html    الوافر    sea-الوافر.html      81
# 2     Poems-Topics-عامه.html    الطويل    sea-الطويل.html      74
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 1. جمع القصائد المطابقة من جميع ملفات الـ JSON
# ----> 2 target_urls = set(abu_alalaa_df['url'])
#       3 matched_batches = []
#       5 for file in list_json:
#
# NameError: name 'abu_alalaa_df' is not defined
