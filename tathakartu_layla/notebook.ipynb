# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
text = Path('./tathakartu_layla.txt').read_text('utf-8').splitlines()
text = [line.strip() for line in text]

df = pd.DataFrame(text).rename(columns={0:'VERSES'})
df['IDX'] = df.index
df['V_ID'] = df['IDX'] // 2
df['GRP'] = df.apply(lambda x: tuple(
    [x['IDX'],  x['VERSES']]
) , axis=1)

df = df.groupby(['V_ID'], as_index=False).agg(
    {'GRP': lambda x: list(x)}
).sort_values(['V_ID']).reset_index(drop=True)
df['GRP'] = df['GRP'].apply(lambda x: sorted(x, key=lambda y: y[0]))
df['VERSES'] = df['GRP'].apply(lambda x: tuple([i[1] for i in x]))
df
# Out:
#     V_ID                                                GRP  \
# 0      0  [(0, تَذَكَّرتُ لَيلى وَالسِنينَ الخَوالِيا), ...
# 1      1  [(2, بِثَمدَينِ لاحَت نارَ لَيلى وَصَحبَتي), (...
# 2      2  [(4, فَقالَ بَصيرُ القَومِ أَلمَحتُ كَوكَباً),...
# 3      3  [(6, فَقُلتُ لَهُ بَل نارَ لَيلى تَوَقَّدَت), ...
# 4      4  [(8, فَلَيتَ رِكابَ القَومِ لَم تَقطَعِ الغَضا...
# ..   ...                                                ...
# 78    78  [(156, وَمَن لَو رَأى الأَعداءَ يَكتَنِفونَني)...
# 79    79  [(158, وَلَم يُنسِني لَيلى اِفتِقارٌ وَلا غِنى...
# 80    80  [(160, وَلا نِسوَةٌ صَبَّغنَ كَبداءَ جَلعَداً)...
# 81    81  [(162, حَلَفتُ لَإِن لاقَيتُ لَيلى بِخَلوَةٍ),...
# 82    82  [(164, شَكَرتُ لِرَبّي إِذ رَأَيتُكِ نَظرَةً),...
#
#                                                VERSES
# 0   (تَذَكَّرتُ لَيلى وَالسِنينَ الخَوالِيا, وَأَي...
# 1   (بِثَمدَينِ لاحَت نارَ لَيلى وَصَحبَتي, بِذاتِ...
# 2   (فَقالَ بَصيرُ القَومِ أَلمَحتُ كَوكَباً, بَدا...
# 3   (فَقُلتُ لَهُ بَل نارَ لَيلى تَوَقَّدَت, بِعَل...
# 4   (فَلَيتَ رِكابَ القَومِ لَم تَقطَعِ الغَضا, وَ...
# ..                                                ...
# 78  (وَمَن لَو رَأى الأَعداءَ يَكتَنِفونَني, لَهُم...
# 79  (وَلَم يُنسِني لَيلى اِفتِقارٌ وَلا غِنى, وَلا...
# 80  (وَلا نِسوَةٌ صَبَّغنَ كَبداءَ جَلعَداً, لِتُش...
# 81  (حَلَفتُ لَإِن لاقَيتُ لَيلى بِخَلوَةٍ, أَطوفُ...
# 82  (شَكَرتُ لِرَبّي إِذ رَأَيتُكِ نَظرَةً, نَظَرت...
#
# [83 rows x 3 columns]

# %%
df['VERSES'].to_json('./MAJNOON_LAYLA.json', orient='records', force_ascii=False)
