# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
text = Path('./ara_alnqa.txt').read_text('utf-8').splitlines()
text = [line.strip() for line in text]

df = pd.DataFrame(text).rename(columns={0:'VERSES'})
df['IDX'] = df.index
df['V_ID'] = df['IDX'] // 2
df['GRP'] = df.apply(lambda x: tuple(
    [x['IDX'],  x['VERSES']]
) , axis=1)

df = df.groupby(['V_ID'], as_index=False).agg(
    {'GRP': lambda x: list(x)}
).sort_values(['V_ID']).reset_index(drop=True)
df['GRP'] = df['GRP'].apply(lambda x: sorted(x, key=lambda y: y[0]))
df['VERSES'] = df['GRP'].apply(lambda x: tuple([i[1] for i in x]))
df
# Out:
#     V_ID                                                GRP  \
# 0      0  [(0, أرى العَنْقاءَ تَكْبُرُ أن تُصادا), (1, ف...
# 1      1  [(2, وما نَهْنَهَتُ عن طَلَبٍ ولكِنْ), (3, هيَ...
# 2      2  [(4, فلا تَلُمِ السّوابِقَ والمَطايا), (5, إذا...
# 3      3  [(6, لعَلّكَ أنْ تَشُنّ بها مَغاراً), (7, فتُن...
# 4      4  [(8, مُقارِعَةً أحِجّتَها العَوالي), (9, مُجَن...
# 5      5  [(10, نَلومُ على تَبلّدِها قُلوباً), (11, تُكا...
# 6      6  [(12, إذا ما النّارُ لم تُطْعَمْ ضِراماً), (13...
# 7      7  [(14, فظُنّ بسائِرِ الإخْوانِ شَرّاً), (15, ول...
# 8      8  [(16, فلو خَبَرَتْهُمُ الجَوزاءُ خُبْري), (17,...
# 9      9  [(18, تَجَنّبْتُ الأنامَ فلا أُواخي), (19, وزِ...
# 10    10  [(20, ولمّا أنْ تَجَهّمَني مُرادي), (21, جَرَي...
# 11    11  [(22, وهَوَّنْتُ الخُطوبَ عليّ حتى), (23, كأني...
# 12    12  [(24, أَأُنْكِرُها ومَنْبِتُها فؤادي), (25, وك...
# 13    13  [(26, فأيّ النّاسِ أجْعَلُهُ صَديقا), (27, وأي...
# 14    14  [(28, ولو أنّ النّجومَ لديّ مالٌ), (29, نَفَتْ...
# 15    15  [(30, كأني في لِسانِ الدهْرِ لَفْظٌ), (31, تَض...
# 16    16  [(32, يُكَرّرُني ليَفَهَمَني رِجالٌ), (33, كما...
# 17    17  [(34, ولو أنّي حُبِيتُ الخُلْدَ فَرْداً), (35,...
# 18    18  [(36, فلا هَطَلَتْ عَلَيّ ولا بأرْضي), (37, سَ...
# 19    19  [(38, وكم مِن طالِبٍ أمَدي سيَلْقى), (39, دُوَ...
# 20    20  [(40, يُؤجِّجُ في شُعاعِ الشمسِ ناراً), (41, و...
# 21    21  [(42, ويَطْعَنُ في عُلايَ وإنّ شِسْعي), (43, ل...
# 22    22  [(44, ويُظْهِرُ لي مَوَدّتَهُ مَقالا), (45, وي...
# 23    23  [(46, فلا وأبيكَ ما أخْشَى انتِقاضاً), (47, ول...
# 24    24  [(48, ليَ الشّرَفُ الّذي يَطَأُ الثُريّا), (49...
# 25    25  [(50, وكم عَيْنٍ تُؤَمّلُ أن تَراني), (51, وتَ...
# 26    26  [(52, ولو مَلأ السُّهى عَيْنَيْهِ مِنّي), (53,...
# 27    27  [(54, أفُلّ نَوائبَ الأيامِ وحْدي), (55, إذا ج...
# 28    28  [(56, وقدْ أَثْبَتُّ رِجْلي في رِكابٍ), (57, ج...
# 29    29  [(58, إذا أوْطَأتُها قَدَمَيْ سُهَيْلٍ), (59, ...
# 30    30  [(60, كأنّ ظِماءَهُنّ بناتُ نَعْشٍ), (61, يَرِ...
# 31    31  [(62, ستَعْجَبُ من تَغَشْمُرِها لَيالٍ), (63, ...
# 32    32  [(64, كأنّ فِجاجَها فَقَدَتْ حَبيباً), (65, فص...
# 33    33  [(66, وقد كتَبَ الضّريبُ بها سُطوراً), (67, فخ...
# 34    34  [(68, كأنّ الزِّبْرِقانَ بها أسيرٌ), (69, تُجُ...
# 35    35  [(70, وبعضُ الظاعِنينَ كقَرْنِ شَمْسٍ), (71, ي...
# 36    36  [(72, ولكِنّي الشّبابُ إذا تَوَلّى), (73, فجَه...
# 37    37  [(74, وأحْسَبُ أنّ قَلْبي لو عَصاني), (75, فَع...
# 38    38  [(76, تذكَّرْتُ البِداوَةَ في أُناسٍ), (77, تَ...
# 39    39  [(78, يَصيدونَ الفَوَارِسَ كلَّ يومٍ), (79, كم...
# 40    40  [(80, طلَعْتُ عليهِمْ واليوْمُ طِفْلٌ), (81, ك...
# 41    41  [(82, إذا نَزَلَ الضّيوفُ ولم يُريحُوا), (83, ...
# 42    42  [(84, بُناةُ الشِّعْرِ ما أكْفَوْا رَوِيّاً), ...
# 43    43  [(86, عَهِدْتُ لأحْسَنِ الحَيّيْنِ وَجْهاً), (...
# 44    44  [(88, وأطْوَلِهِمْ إذا ركِبوا قَناةً), (89, وأ...
# 45    45  [(90, فتىً يَهَبُ اللُّجَيْنَ المَحضَ جوداً), ...
# 46    46  [(92, ويَلْبَسُ من جُلودِ عِداهُ سِبْتاً), (93...
# 47    47  [(94, أبَنَّ الغَزْوَ مُكْتَهِلاً وبَدْرا), (9...
# 48    48  [(96, جَهولٌ بالمَناسِكِ ليس يَدري), (97, أغَي...
# 49    49  [(98, طَموحُ السّيفِ لا يخْشَى إلهاً), (99, ول...
# 50    50  [(100, ويَغْبِقُ أهْلَهُ لبَنَ الصّفايا), (101...
# 51    51  [(102, يَذودُ سَخاؤُهَ الأذْوادَ عنه), (103, و...
# 52    52  [(104, يَرُدّ بتُرْسِهِ النّكْباءَ عنّي), (105...
# 53    53  [(106, فبِتُّ وإنّما ألْقَى خَيَالاً), (107, ك...
# 54    54  [(108, وأطْلَسَ مُخْلِقِ السِّرْبالِ يَبْغي), ...
# 55    55  [(110, كأنّي إذْ نَبَذْتُ له عِصاماً), (111, و...
# 56    56  [(112, وبَالي الجِسْمِ كالذّكَرِ اليَماني), (1...
# 57    57  [(114, طَرَحْتُ له الوَضِينَ فخِلْتُ أني), (11...
# 58    58  [(116, وَلي نَفْسٌ تَحُلّ بيَ الرّوابي), (117,...
# 59    59  [(118, تَمُدّ لتَقْبِضَ القَمَرَينِ كَفّا), (1...
#
#                                                VERSES
# 0   (أرى العَنْقاءَ تَكْبُرُ أن تُصادا, فعانِدْ مَ...
# 1   (وما نَهْنَهَتُ عن طَلَبٍ ولكِنْ, هيَ الأيّامُ...
# 2   (فلا تَلُمِ السّوابِقَ والمَطايا, إذا غَرَضٌ م...
# 3   (لعَلّكَ أنْ تَشُنّ بها مَغاراً, فتُنْجِحَ أو ...
# 4   (مُقارِعَةً أحِجّتَها العَوالي, مُجَنّبَةً نَو...
# 5   (نَلومُ على تَبلّدِها قُلوباً, تُكابِدُ من مَع...
# 6   (إذا ما النّارُ لم تُطْعَمْ ضِراماً, فأوْشِكْ ...
# 7   (فظُنّ بسائِرِ الإخْوانِ شَرّاً, ولا تأمَنْ عل...
# 8   (فلو خَبَرَتْهُمُ الجَوزاءُ خُبْري, لَما طَلَع...
# 9   (تَجَنّبْتُ الأنامَ فلا أُواخي, وزِدْتُ عن الع...
# 10  (ولمّا أنْ تَجَهّمَني مُرادي, جَرَيْتُ معَ الز...
# 11  (وهَوَّنْتُ الخُطوبَ عليّ حتى, كأني صِرتُ أمْن...
# 12  (أَأُنْكِرُها ومَنْبِتُها فؤادي, وكيفَ تُناكِر...
# 13  (فأيّ النّاسِ أجْعَلُهُ صَديقا, وأيّ الأرضِ أس...
# 14  (ولو أنّ النّجومَ لديّ مالٌ, نَفَتْ كَفّايَ أك...
# 15  (كأني في لِسانِ الدهْرِ لَفْظٌ, تَضَمّنَ منه أ...
# 16  (يُكَرّرُني ليَفَهَمَني رِجالٌ, كما كَرّرْتَ م...
# 17  (ولو أنّي حُبِيتُ الخُلْدَ فَرْداً, لمَا أحبَب...
# 18  (فلا هَطَلَتْ عَلَيّ ولا بأرْضي, سَحائبُ ليسَ ...
# 19  (وكم مِن طالِبٍ أمَدي سيَلْقى, دُوَيْنَ مَكاني...
# 20  (يُؤجِّجُ في شُعاعِ الشمسِ ناراً, ويَقْدَحُ في...
# 21  (ويَطْعَنُ في عُلايَ وإنّ شِسْعي, لَيَأنَفُ أن...
# 22  (ويُظْهِرُ لي مَوَدّتَهُ مَقالا, ويُبْغِضُني ض...
# 23  (فلا وأبيكَ ما أخْشَى انتِقاضاً, ولا وأبيكَ ما...
# 24  (ليَ الشّرَفُ الّذي يَطَأُ الثُريّا, معَ الفَض...
# 25  (وكم عَيْنٍ تُؤَمّلُ أن تَراني, وتَفْقِدُ عندَ...
# 26  (ولو مَلأ السُّهى عَيْنَيْهِ مِنّي, أَبَرَّ عل...
# 27  (أفُلّ نَوائبَ الأيامِ وحْدي, إذا جَمَعَتْ كَت...
# 28  (وقدْ أَثْبَتُّ رِجْلي في رِكابٍ, جَعَلْتُ من ...
# 29  (إذا أوْطَأتُها قَدَمَيْ سُهَيْلٍ, فلا سُقِيَت...
# 30  (كأنّ ظِماءَهُنّ بناتُ نَعْشٍ, يَرِدْنَ إذا وَ...
# 31  (ستَعْجَبُ من تَغَشْمُرِها لَيالٍ, تُبارِينا ك...
# 32  (كأنّ فِجاجَها فَقَدَتْ حَبيباً, فصَيّرَتِ الظ...
# 33  (وقد كتَبَ الضّريبُ بها سُطوراً, فخِلْتَ الأرض...
# 34  (كأنّ الزِّبْرِقانَ بها أسيرٌ, تُجُنِّبَ لا يُ...
# 35  (وبعضُ الظاعِنينَ كقَرْنِ شَمْسٍ, يَغيبُ فإنْ ...
# 36  (ولكِنّي الشّبابُ إذا تَوَلّى, فجَهْلٌ أنْ تَر...
# 37  (وأحْسَبُ أنّ قَلْبي لو عَصاني, فَعاوَدَ ما وَ...
# 38  (تذكَّرْتُ البِداوَةَ في أُناسٍ, تَخالُ رَبيعَ...
# 39  (يَصيدونَ الفَوَارِسَ كلَّ يومٍ, كما تَتَصَيّد...
# 40  (طلَعْتُ عليهِمْ واليوْمُ طِفْلٌ, كأنّ على مَش...
# 41  (إذا نَزَلَ الضّيوفُ ولم يُريحُوا, كرامَ سَوام...
# 42  (بُناةُ الشِّعْرِ ما أكْفَوْا رَوِيّاً, ولا عَ...
# 43  (عَهِدْتُ لأحْسَنِ الحَيّيْنِ وَجْهاً, وأوْهَب...
# 44  (وأطْوَلِهِمْ إذا ركِبوا قَناةً, وأرْفَعِهِمْ ...
# 45  (فتىً يَهَبُ اللُّجَيْنَ المَحضَ جوداً, ويَدَّ...
# 46  (ويَلْبَسُ من جُلودِ عِداهُ سِبْتاً, ويَرْفَعُ...
# 47  (أبَنَّ الغَزْوَ مُكْتَهِلاً وبَدْرا, وعُوّدَ ...
# 48  (جَهولٌ بالمَناسِكِ ليس يَدري, أغَيّاً باتَ يَ...
# 49  (طَموحُ السّيفِ لا يخْشَى إلهاً, ولا يَرجو الق...
# 50  (ويَغْبِقُ أهْلَهُ لبَنَ الصّفايا, ويَمْنَحُ ق...
# 51  (يَذودُ سَخاؤُهَ الأذْوادَ عنه, ويُحْسِنُ عن ح...
# 52  (يَرُدّ بتُرْسِهِ النّكْباءَ عنّي, ويجْعَلُ دِ...
# 53  (فبِتُّ وإنّما ألْقَى خَيَالاً, كمَنْ يَلْقَى ...
# 54  (وأطْلَسَ مُخْلِقِ السِّرْبالِ يَبْغي, نَوافِل...
# 55  (كأنّي إذْ نَبَذْتُ له عِصاماً, وَهَبْتُ له ال...
# 56  (وبَالي الجِسْمِ كالذّكَرِ اليَماني, أفُلّ به ...
# 57  (طَرَحْتُ له الوَضِينَ فخِلْتُ أني, طرَحْتُ له...
# 58  (وَلي نَفْسٌ تَحُلّ بيَ الرّوابي, وتأبَى أنْ ت...
# 59  (تَمُدّ لتَقْبِضَ القَمَرَينِ كَفّا, وتَحْمِلُ...

# %%
df['VERSES'].to_json('./ara_alnqa.json', orient='records', force_ascii=False)
